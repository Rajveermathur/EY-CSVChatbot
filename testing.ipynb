# %%
# %pip install sqlalchemy
# Out:
# Requirement already satisfied: sqlalchemy in c:\users\rajveer.mathur\onedrive - brillio\desktop\ey\.venv\lib\site-packages (2.0.31)
# Requirement already satisfied: typing-extensions>=4.6.0 in c:\users\rajveer.mathur\onedrive - brillio\desktop\ey\.venv\lib\site-packages (from sqlalchemy) (4.12.2)
# Requirement already satisfied: greenlet!=0.4.17 in c:\users\rajveer.mathur\onedrive - brillio\desktop\ey\.venv\lib\site-packages (from sqlalchemy) (3.0.3)
# Note: you may need to restart the kernel to use updated packages.
# [notice] A new release of pip is available: 24.1.1 -> 24.1.2
# [notice] To update, run: python.exe -m pip install --upgrade pip

# %%
import pandas as pd

df = pd.read_csv("ai4i2020.csv")
print(df.shape)
print(df.columns.tolist())
# Out:
# (36, 14)
# ['UDI', 'Product ID', 'Type', 'Air temperature [K]', 'Process temperature [K]', 'Rotational speed [rpm]', 'Torque [Nm]', 'Tool wear [min]', 'Machine failure', 'TWF', 'HDF', 'PWF', 'OSF', 'RNF']

# %%
from langchain_community.utilities import SQLDatabase
from sqlalchemy import create_engine

engine = create_engine("sqlite:///titanic.db")
df.to_sql("titanic", engine, index=False)
# Out:
# 36

# %%
db = SQLDatabase(engine=engine)
print(db.dialect)
print(db.get_usable_table_names())
db.run("SELECT * FROM titanic;")
# Out:
# sqlite
# ['titanic']
# "[(1, 'M14860', 'M', 298.1, 308.6, 1551, 42.8, 0, 0, 0, 0, 0, 0, 0), (2, 'L47181', 'L', 298.2, 308.7, 1408, 46.3, 3, 0, 0, 0, 0, 0, 0), (3, 'L47182', 'L', 298.1, 308.5, 1498, 49.4, 5, 0, 0, 0, 0, 0, 0), (4, 'L47183', 'L', 298.2, 308.6, 1433, 39.5, 7, 0, 0, 0, 0, 0, 0), (5, 'L47184', 'L', 298.2, 308.7, 1408, 40.0, 9, 0, 0, 0, 0, 0, 0), (6, 'M14865', 'M', 298.1, 308.6, 1425, 41.9, 11, 0, 0, 0, 0, 0, 0), (7, 'L47186', 'L', 298.1, 308.6, 1558, 42.4, 14, 0, 0, 0, 0, 0, 0), (8, 'L47187', 'L', 298.1, 308.6, 1527, 40.2, 16, 0, 0, 0, 0, 0, 0), (9, 'M14868', 'M', 298.3, 308.7, 1667, 28.6, 18, 0, 0, 0, 0, 0, 0), (10, 'M14869', 'M', 298.5, 309.0, 1741, 28.0, 21, 0, 0, 0, 0, 0, 0), (11, 'H29424', 'H', 298.4, 308.9, 1782, 23.9, 24, 0, 0, 0, 0, 0, 0), (12, 'H29425', 'H', 298.6, 309.1, 1423, 44.3, 29, 0, 0, 0, 0, 0, 0), (13, 'M14872', 'M', 298.6, 309.1, 1339, 51.1, 34, 0, 0, 0, 0, 0, 0), (14, 'M14873', 'M', 298.6, 309.2, 1742, 30.0, 37, 0, 0, 0, 0, 0, 0), (15, 'L47194', 'L', 298.6, 309.2, 2035, 19.6, 40, 0, 0, 0, 0, 0, 0), (16, 'L47195', 'L', 298.6, 309.2, 1542, 48.4, 42, 0, 0, 0, 0, 0, 0), (17, 'M14876', 'M', 298.6, 309.2, 1311, 46.6, 44, 0, 0, 0, 0, 0, 0), (18, 'M14877', 'M', 298.7, 309.2, 1410, 45.6, 47, 0, 0, 0, 0, 0, 0), (19, 'H29432', 'H', 298.8, 309.2, 1306, 54.5, 50, 0, 0, 0, 0, 0, 0), (20, 'M14879', 'M', 298.9, 309.3, 1632, 32.5, 55, 0, 0, 0, 0, 0, 0), (21, 'H29434', 'H', 298.9, 309.3, 1375, 42.7, 58, 0, 0, 0, 0, 0, 0), (22, 'L47201', 'L', 298.8, 309.3, 1450, 44.8, 63, 0, 0, 0, 0, 0, 0), (23, 'M14882', 'M', 298.9, 309.3, 1581, 30.7, 65, 0, 0, 0, 0, 0, 0), (24, 'L47203', 'L', 299.0, 309.4, 1758, 25.7, 68, 0, 0, 0, 0, 0, 0), (25, 'M14884', 'M', 299.0, 309.4, 1561, 37.3, 70, 0, 0, 0, 0, 0, 0), (26, 'L47205', 'L', 299.0, 309.5, 1861, 23.3, 73, 0, 0, 0, 0, 0, 0), (27, 'L47206', 'L', 299.1, 309.5, 1512, 39.0, 75, 0, 0, 0, 0, 0, 0), (28, 'H29441', 'H', 299.1, 309.4, 1811, 24.6, 77, 0, 0, 0, 0, 0, 0), (29, 'L47208', 'L', 299.1, 309.4, 1439, 44.2, 82, 0, 0, 0, 0, 0, 0), (30, 'L47209', 'L', 299.0, 309.4, 1693, 30.1, 84, 0, 0, 0, 0, 0, 0), (31, 'M14890', 'M', 299.1, 309.5, 1339, 48.2, 86, 0, 0, 0, 0, 0, 0), (32, 'L47211', 'L', 299.0, 309.4, 1798, 25.5, 89, 0, 0, 0, 0, 0, 0), (33, 'L47212', 'L', 299.0, 309.4, 1419, 48.3, 91, 0, 0, 0, 0, 0, 0), (34, 'L47213', 'L', 298.9, 309.3, 1665, 32.5, 93, 0, 0, 0, 0, 0, 0), (35, 'M14894', 'M', 298.8, 309.1, 1559, 34.7, 95, 0, 0, 0, 0, 0, 0), (36, 'M14895', 'M', 298.8, 309.2, 1452, 48.6, 98, 0, 0, 0, 0, 0, 0)]"

# %%
from langchain_community.agent_toolkits import create_sql_agent
from langchain_groq import ChatGroq

llm = ChatGroq(
    temperature=0.2,
    model="mixtral-8x7b-32768",
    api_key=""
)

agent_executor = create_sql_agent(llm, db=db, agent_type="openai-tools", verbose=True)

# %%
agent_executor.invoke({"input": "What is total number of rows?"})
# Out:
# > Entering new SQL Agent Executor chain...
# ---------------------------------------------------------------------------
# ConnectError                              Traceback (most recent call last)
# File c:\Users\Rajveer.Mathur\OneDrive - Brillio\Desktop\EY\.venv\Lib\site-packages\httpx\_transports\default.py:69, in map_httpcore_exceptions()
#      68 try:
# ---> 69     yield
#      70 except Exception as exc:
#
# File c:\Users\Rajveer.Mathur\OneDrive - Brillio\Desktop\EY\.venv\Lib\site-packages\httpx\_transports\default.py:233, in HTTPTransport.handle_request(self, request)
#     232 with map_httpcore_exceptions():
# --> 233     resp = self._pool.handle_request(req)
#     235 assert isinstance(resp.stream, typing.Iterable)
#
# File c:\Users\Rajveer.Mathur\OneDrive - Brillio\Desktop\EY\.venv\Lib\site-packages\httpcore\_sync\connection_pool.py:216, in ConnectionPool.handle_request(self, request)
#     215     self._close_connections(closing)
# --> 216     raise exc from None
#     218 # Return the response. Note that in this case we still have to manage
#     219 # the point at which the response is closed.
#
# File c:\Users\Rajveer.Mathur\OneDrive - Brillio\Desktop\EY\.venv\Lib\site-packages\httpcore\_sync\connection_pool.py:196, in ConnectionPool.handle_request(self, request)
#     194 try:
#     195     # Send the request on the assigned connection.
# --> 196     response = connection.handle_request(
#     197         pool_request.request
#     198     )
#     199 except ConnectionNotAvailable:
#     200     # In some cases a connection may initially be available to
#     201     # handle a request, but then become unavailable.
#     202     #
#     203     # In this case we clear the connection and try again.
#
# File c:\Users\Rajveer.Mathur\OneDrive - Brillio\Desktop\EY\.venv\Lib\site-packages\httpcore\_sync\connection.py:99, in HTTPConnection.handle_request(self, request)
#      98     self._connect_failed = True
# ---> 99     raise exc
#     101 return self._connection.handle_request(request)
#
# File c:\Users\Rajveer.Mathur\OneDrive - Brillio\Desktop\EY\.venv\Lib\site-packages\httpcore\_sync\connection.py:76, in HTTPConnection.handle_request(self, request)
#      75 if self._connection is None:
# ---> 76     stream = self._connect(request)
#      78     ssl_object = stream.get_extra_info("ssl_object")
#
# File c:\Users\Rajveer.Mathur\OneDrive - Brillio\Desktop\EY\.venv\Lib\site-packages\httpcore\_sync\connection.py:154, in HTTPConnection._connect(self, request)
#     153 with Trace("start_tls", logger, request, kwargs) as trace:
# --> 154     stream = stream.start_tls(**kwargs)
#     155     trace.return_value = stream
#
# File c:\Users\Rajveer.Mathur\OneDrive - Brillio\Desktop\EY\.venv\Lib\site-packages\httpcore\_backends\sync.py:152, in SyncStream.start_tls(self, ssl_context, server_hostname, timeout)
#     148 exc_map: ExceptionMapping = {
#     149     socket.timeout: ConnectTimeout,
#     150     OSError: ConnectError,
#     151 }
# --> 152 with map_exceptions(exc_map):
#     153     try:
#
# File C:\Program Files\Python311\Lib\contextlib.py:155, in _GeneratorContextManager.__exit__(self, typ, value, traceback)
#     154 try:
# --> 155     self.gen.throw(typ, value, traceback)
#     156 except StopIteration as exc:
#     157     # Suppress StopIteration *unless* it's the same exception that
#     158     # was passed to throw().  This prevents a StopIteration
#     159     # raised inside the "with" statement from being suppressed.
#
# File c:\Users\Rajveer.Mathur\OneDrive - Brillio\Desktop\EY\.venv\Lib\site-packages\httpcore\_exceptions.py:14, in map_exceptions(map)
#      13     if isinstance(exc, from_exc):
# ---> 14         raise to_exc(exc) from exc
#      15 raise
#
# ConnectError: [SSL: CERTIFICATE_VERIFY_FAILED] certificate verify failed: unable to get local issuer certificate (_ssl.c:1006)
#
# The above exception was the direct cause of the following exception:
#
# ConnectError                              Traceback (most recent call last)
# File c:\Users\Rajveer.Mathur\OneDrive - Brillio\Desktop\EY\.venv\Lib\site-packages\groq\_base_client.py:951, in SyncAPIClient._request(self, cast_to, options, remaining_retries, stream, stream_cls)
#     950 try:
# --> 951     response = self._client.send(
#     952         request,
#     953         stream=stream or self._should_stream_response_body(request=request),
#     954         **kwargs,
#     955     )
#     956 except httpx.TimeoutException as err:
#
# File c:\Users\Rajveer.Mathur\OneDrive - Brillio\Desktop\EY\.venv\Lib\site-packages\httpx\_client.py:914, in Client.send(self, request, stream, auth, follow_redirects)
#     912 auth = self._build_request_auth(request, auth)
# --> 914 response = self._send_handling_auth(
#     915     request,
#     916     auth=auth,
#     917     follow_redirects=follow_redirects,
#     918     history=[],
#     919 )
#     920 try:
#
# File c:\Users\Rajveer.Mathur\OneDrive - Brillio\Desktop\EY\.venv\Lib\site-packages\httpx\_client.py:942, in Client._send_handling_auth(self, request, auth, follow_redirects, history)
#     941 while True:
# --> 942     response = self._send_handling_redirects(
#     943         request,
#     944         follow_redirects=follow_redirects,
#     945         history=history,
#     946     )
#     947     try:
#
# File c:\Users\Rajveer.Mathur\OneDrive - Brillio\Desktop\EY\.venv\Lib\site-packages\httpx\_client.py:979, in Client._send_handling_redirects(self, request, follow_redirects, history)
#     977     hook(request)
# --> 979 response = self._send_single_request(request)
#     980 try:
#
# File c:\Users\Rajveer.Mathur\OneDrive - Brillio\Desktop\EY\.venv\Lib\site-packages\httpx\_client.py:1015, in Client._send_single_request(self, request)
#    1014 with request_context(request=request):
# -> 1015     response = transport.handle_request(request)
#    1017 assert isinstance(response.stream, SyncByteStream)
#
# File c:\Users\Rajveer.Mathur\OneDrive - Brillio\Desktop\EY\.venv\Lib\site-packages\httpx\_transports\default.py:232, in HTTPTransport.handle_request(self, request)
#     220 req = httpcore.Request(
#     221     method=request.method,
#     222     url=httpcore.URL(
#    (...)
#     230     extensions=request.extensions,
#     231 )
# --> 232 with map_httpcore_exceptions():
#     233     resp = self._pool.handle_request(req)
#
# File C:\Program Files\Python311\Lib\contextlib.py:155, in _GeneratorContextManager.__exit__(self, typ, value, traceback)
#     154 try:
# --> 155     self.gen.throw(typ, value, traceback)
#     156 except StopIteration as exc:
#     157     # Suppress StopIteration *unless* it's the same exception that
#     158     # was passed to throw().  This prevents a StopIteration
#     159     # raised inside the "with" statement from being suppressed.
#
# File c:\Users\Rajveer.Mathur\OneDrive - Brillio\Desktop\EY\.venv\Lib\site-packages\httpx\_transports\default.py:86, in map_httpcore_exceptions()
#      85 message = str(exc)
# ---> 86 raise mapped_exc(message) from exc
#
# ConnectError: [SSL: CERTIFICATE_VERIFY_FAILED] certificate verify failed: unable to get local issuer certificate (_ssl.c:1006)
#
# The above exception was the direct cause of the following exception:
#
# APIConnectionError                        Traceback (most recent call last)
# Cell In[6], line 1
# ----> 1 agent_executor.invoke({"input": "What is total number of rows?"})
#
# File c:\Users\Rajveer.Mathur\OneDrive - Brillio\Desktop\EY\.venv\Lib\site-packages\langchain\chains\base.py:166, in Chain.invoke(self, input, config, **kwargs)
#     164 except BaseException as e:
#     165     run_manager.on_chain_error(e)
# --> 166     raise e
#     167 run_manager.on_chain_end(outputs)
#     169 if include_run_info:
#
# File c:\Users\Rajveer.Mathur\OneDrive - Brillio\Desktop\EY\.venv\Lib\site-packages\langchain\chains\base.py:156, in Chain.invoke(self, input, config, **kwargs)
#     153 try:
#     154     self._validate_inputs(inputs)
#     155     outputs = (
# --> 156         self._call(inputs, run_manager=run_manager)
#     157         if new_arg_supported
#     158         else self._call(inputs)
#     159     )
#     161     final_outputs: Dict[str, Any] = self.prep_outputs(
#     162         inputs, outputs, return_only_outputs
#     163     )
#     164 except BaseException as e:
#
# File c:\Users\Rajveer.Mathur\OneDrive - Brillio\Desktop\EY\.venv\Lib\site-packages\langchain\agents\agent.py:1433, in AgentExecutor._call(self, inputs, run_manager)
#    1431 # We now enter the agent loop (until it returns something).
#    1432 while self._should_continue(iterations, time_elapsed):
# -> 1433     next_step_output = self._take_next_step(
#    1434         name_to_tool_map,
#    1435         color_mapping,
#    1436         inputs,
#    1437         intermediate_steps,
#    1438         run_manager=run_manager,
#    1439     )
#    1440     if isinstance(next_step_output, AgentFinish):
#    1441         return self._return(
#    1442             next_step_output, intermediate_steps, run_manager=run_manager
#    1443         )
#
# File c:\Users\Rajveer.Mathur\OneDrive - Brillio\Desktop\EY\.venv\Lib\site-packages\langchain\agents\agent.py:1139, in AgentExecutor._take_next_step(self, name_to_tool_map, color_mapping, inputs, intermediate_steps, run_manager)
#    1130 def _take_next_step(
#    1131     self,
#    1132     name_to_tool_map: Dict[str, BaseTool],
#    (...)
#    1136     run_manager: Optional[CallbackManagerForChainRun] = None,
#    1137 ) -> Union[AgentFinish, List[Tuple[AgentAction, str]]]:
#    1138     return self._consume_next_step(
# -> 1139         [
#    1140             a
#    1141             for a in self._iter_next_step(
#    1142                 name_to_tool_map,
#    1143                 color_mapping,
#    1144                 inputs,
#    1145                 intermediate_steps,
#    1146                 run_manager,
#    1147             )
#    1148         ]
#    1149     )
#
# File c:\Users\Rajveer.Mathur\OneDrive - Brillio\Desktop\EY\.venv\Lib\site-packages\langchain\agents\agent.py:1139, in <listcomp>(.0)
#    1130 def _take_next_step(
#    1131     self,
#    1132     name_to_tool_map: Dict[str, BaseTool],
#    (...)
#    1136     run_manager: Optional[CallbackManagerForChainRun] = None,
#    1137 ) -> Union[AgentFinish, List[Tuple[AgentAction, str]]]:
#    1138     return self._consume_next_step(
# -> 1139         [
#    1140             a
#    1141             for a in self._iter_next_step(
#    1142                 name_to_tool_map,
#    1143                 color_mapping,
#    1144                 inputs,
#    1145                 intermediate_steps,
#    1146                 run_manager,
#    1147             )
#    1148         ]
#    1149     )
#
# File c:\Users\Rajveer.Mathur\OneDrive - Brillio\Desktop\EY\.venv\Lib\site-packages\langchain\agents\agent.py:1167, in AgentExecutor._iter_next_step(self, name_to_tool_map, color_mapping, inputs, intermediate_steps, run_manager)
#    1164     intermediate_steps = self._prepare_intermediate_steps(intermediate_steps)
#    1166     # Call the LLM to see what to do.
# -> 1167     output = self.agent.plan(
#    1168         intermediate_steps,
#    1169         callbacks=run_manager.get_child() if run_manager else None,
#    1170         **inputs,
#    1171     )
#    1172 except OutputParserException as e:
#    1173     if isinstance(self.handle_parsing_errors, bool):
#
# File c:\Users\Rajveer.Mathur\OneDrive - Brillio\Desktop\EY\.venv\Lib\site-packages\langchain\agents\agent.py:515, in RunnableMultiActionAgent.plan(self, intermediate_steps, callbacks, **kwargs)
#     507 final_output: Any = None
#     508 if self.stream_runnable:
#     509     # Use streaming to make sure that the underlying LLM is invoked in a
#     510     # streaming
#    (...)
#     513     # Because the response from the plan is not a generator, we need to
#     514     # accumulate the output into final output and return that.
# --> 515     for chunk in self.runnable.stream(inputs, config={"callbacks": callbacks}):
#     516         if final_output is None:
#     517             final_output = chunk
#
# File c:\Users\Rajveer.Mathur\OneDrive - Brillio\Desktop\EY\.venv\Lib\site-packages\langchain_core\runnables\base.py:2885, in RunnableSequence.stream(self, input, config, **kwargs)
#    2879 def stream(
#    2880     self,
#    2881     input: Input,
#    2882     config: Optional[RunnableConfig] = None,
#    2883     **kwargs: Optional[Any],
#    2884 ) -> Iterator[Output]:
# -> 2885     yield from self.transform(iter([input]), config, **kwargs)
#
# File c:\Users\Rajveer.Mathur\OneDrive - Brillio\Desktop\EY\.venv\Lib\site-packages\langchain_core\runnables\base.py:2872, in RunnableSequence.transform(self, input, config, **kwargs)
#    2866 def transform(
#    2867     self,
#    2868     input: Iterator[Input],
#    2869     config: Optional[RunnableConfig] = None,
#    2870     **kwargs: Optional[Any],
#    2871 ) -> Iterator[Output]:
# -> 2872     yield from self._transform_stream_with_config(
#    2873         input,
#    2874         self._transform,
#    2875         patch_config(config, run_name=(config or {}).get("run_name") or self.name),
#    2876         **kwargs,
#    2877     )
#
# File c:\Users\Rajveer.Mathur\OneDrive - Brillio\Desktop\EY\.venv\Lib\site-packages\langchain_core\runnables\base.py:1868, in Runnable._transform_stream_with_config(self, input, transformer, config, run_type, **kwargs)
#    1866 try:
#    1867     while True:
# -> 1868         chunk: Output = context.run(next, iterator)  # type: ignore
#    1869         yield chunk
#    1870         if final_output_supported:
#
# File c:\Users\Rajveer.Mathur\OneDrive - Brillio\Desktop\EY\.venv\Lib\site-packages\langchain_core\runnables\base.py:2834, in RunnableSequence._transform(self, input, run_manager, config, **kwargs)
#    2831     else:
#    2832         final_pipeline = step.transform(final_pipeline, config)
# -> 2834 for output in final_pipeline:
#    2835     yield output
#
# File c:\Users\Rajveer.Mathur\OneDrive - Brillio\Desktop\EY\.venv\Lib\site-packages\langchain_core\runnables\base.py:1163, in Runnable.transform(self, input, config, **kwargs)
#    1160 final: Input
#    1161 got_first_val = False
# -> 1163 for ichunk in input:
#    1164     # The default implementation of transform is to buffer input and
#    1165     # then call stream.
#    1166     # It'll attempt to gather all input into a single chunk using
#    1167     # the `+` operator.
#    1168     # If the input is not addable, then we'll assume that we can
#    1169     # only operate on the last chunk,
#    1170     # and we'll iterate until we get to the last chunk.
#    1171     if not got_first_val:
#    1172         final = ichunk
#
# File c:\Users\Rajveer.Mathur\OneDrive - Brillio\Desktop\EY\.venv\Lib\site-packages\langchain_core\runnables\base.py:4799, in RunnableBindingBase.transform(self, input, config, **kwargs)
#    4793 def transform(
#    4794     self,
#    4795     input: Iterator[Input],
#    4796     config: Optional[RunnableConfig] = None,
#    4797     **kwargs: Any,
#    4798 ) -> Iterator[Output]:
# -> 4799     yield from self.bound.transform(
#    4800         input,
#    4801         self._merge_configs(config),
#    4802         **{**self.kwargs, **kwargs},
#    4803     )
#
# File c:\Users\Rajveer.Mathur\OneDrive - Brillio\Desktop\EY\.venv\Lib\site-packages\langchain_core\runnables\base.py:1181, in Runnable.transform(self, input, config, **kwargs)
#    1178             final = ichunk
#    1180 if got_first_val:
# -> 1181     yield from self.stream(final, config, **kwargs)
#
# File c:\Users\Rajveer.Mathur\OneDrive - Brillio\Desktop\EY\.venv\Lib\site-packages\langchain_core\language_models\chat_models.py:343, in BaseChatModel.stream(self, input, config, stop, **kwargs)
#     336 except BaseException as e:
#     337     run_manager.on_llm_error(
#     338         e,
#     339         response=LLMResult(
#     340             generations=[[generation]] if generation else []
#     341         ),
#     342     )
# --> 343     raise e
#     344 else:
#     345     run_manager.on_llm_end(LLMResult(generations=[[generation]]))
#
# File c:\Users\Rajveer.Mathur\OneDrive - Brillio\Desktop\EY\.venv\Lib\site-packages\langchain_core\language_models\chat_models.py:323, in BaseChatModel.stream(self, input, config, stop, **kwargs)
#     321 generation: Optional[ChatGenerationChunk] = None
#     322 try:
# --> 323     for chunk in self._stream(messages, stop=stop, **kwargs):
#     324         if chunk.message.id is None:
#     325             chunk.message.id = f"run-{run_manager.run_id}"
#
# File c:\Users\Rajveer.Mathur\OneDrive - Brillio\Desktop\EY\.venv\Lib\site-packages\langchain_groq\chat_models.py:507, in ChatGroq._stream(self, messages, stop, run_manager, **kwargs)
#     505 # groq api does not support streaming with tools yet
#     506 if "tools" in kwargs:
# --> 507     response = self.client.create(
#     508         messages=message_dicts, **{**params, **kwargs}
#     509     )
#     510     chat_result = self._create_chat_result(response)
#     511     generation = chat_result.generations[0]
#
# File c:\Users\Rajveer.Mathur\OneDrive - Brillio\Desktop\EY\.venv\Lib\site-packages\groq\resources\chat\completions.py:289, in Completions.create(self, messages, model, frequency_penalty, function_call, functions, logit_bias, logprobs, max_tokens, n, parallel_tool_calls, presence_penalty, response_format, seed, stop, stream, temperature, tool_choice, tools, top_logprobs, top_p, user, extra_headers, extra_query, extra_body, timeout)
#     148 def create(
#     149     self,
#     150     *,
#    (...)
#     177     timeout: float | httpx.Timeout | None | NotGiven = NOT_GIVEN,
#     178 ) -> ChatCompletion | Stream[ChatCompletionChunk]:
#     179     """
#     180     Creates a model response for the given chat conversation.
#     181
#    (...)
#     287       timeout: Override the client-level default timeout for this request, in seconds
#     288     """
# --> 289     return self._post(
#     290         "/openai/v1/chat/completions",
#     291         body=maybe_transform(
#     292             {
#     293                 "messages": messages,
#     294                 "model": model,
#     295                 "frequency_penalty": frequency_penalty,
#     296                 "function_call": function_call,
#     297                 "functions": functions,
#     298                 "logit_bias": logit_bias,
#     299                 "logprobs": logprobs,
#     300                 "max_tokens": max_tokens,
#     301                 "n": n,
#     302                 "parallel_tool_calls": parallel_tool_calls,
#     303                 "presence_penalty": presence_penalty,
#     304                 "response_format": response_format,
#     305                 "seed": seed,
#     306                 "stop": stop,
#     307                 "stream": stream,
#     308                 "temperature": temperature,
#     309                 "tool_choice": tool_choice,
#     310                 "tools": tools,
#     311                 "top_logprobs": top_logprobs,
#     312                 "top_p": top_p,
#     313                 "user": user,
#     314             },
#     315             completion_create_params.CompletionCreateParams,
#     316         ),
#     317         options=make_request_options(
#     318             extra_headers=extra_headers, extra_query=extra_query, extra_body=extra_body, timeout=timeout
#     319         ),
#     320         cast_to=ChatCompletion,
#     321         stream=stream or False,
#     322         stream_cls=Stream[ChatCompletionChunk],
#     323     )
#
# File c:\Users\Rajveer.Mathur\OneDrive - Brillio\Desktop\EY\.venv\Lib\site-packages\groq\_base_client.py:1225, in SyncAPIClient.post(self, path, cast_to, body, options, files, stream, stream_cls)
#    1211 def post(
#    1212     self,
#    1213     path: str,
#    (...)
#    1220     stream_cls: type[_StreamT] | None = None,
#    1221 ) -> ResponseT | _StreamT:
#    1222     opts = FinalRequestOptions.construct(
#    1223         method="post", url=path, json_data=body, files=to_httpx_files(files), **options
#    1224     )
# -> 1225     return cast(ResponseT, self.request(cast_to, opts, stream=stream, stream_cls=stream_cls))
#
# File c:\Users\Rajveer.Mathur\OneDrive - Brillio\Desktop\EY\.venv\Lib\site-packages\groq\_base_client.py:920, in SyncAPIClient.request(self, cast_to, options, remaining_retries, stream, stream_cls)
#     911 def request(
#     912     self,
#     913     cast_to: Type[ResponseT],
#    (...)
#     918     stream_cls: type[_StreamT] | None = None,
#     919 ) -> ResponseT | _StreamT:
# --> 920     return self._request(
#     921         cast_to=cast_to,
#     922         options=options,
#     923         stream=stream,
#     924         stream_cls=stream_cls,
#     925         remaining_retries=remaining_retries,
#     926     )
#
# File c:\Users\Rajveer.Mathur\OneDrive - Brillio\Desktop\EY\.venv\Lib\site-packages\groq\_base_client.py:975, in SyncAPIClient._request(self, cast_to, options, remaining_retries, stream, stream_cls)
#     972 log.debug("Encountered Exception", exc_info=True)
#     974 if retries > 0:
# --> 975     return self._retry_request(
#     976         options,
#     977         cast_to,
#     978         retries,
#     979         stream=stream,
#     980         stream_cls=stream_cls,
#     981         response_headers=None,
#     982     )
#     984 log.debug("Raising connection error")
#     985 raise APIConnectionError(request=request) from err
#
# File c:\Users\Rajveer.Mathur\OneDrive - Brillio\Desktop\EY\.venv\Lib\site-packages\groq\_base_client.py:1051, in SyncAPIClient._retry_request(self, options, cast_to, remaining_retries, response_headers, stream, stream_cls)
#    1047 # In a synchronous context we are blocking the entire thread. Up to the library user to run the client in a
#    1048 # different thread if necessary.
#    1049 time.sleep(timeout)
# -> 1051 return self._request(
#    1052     options=options,
#    1053     cast_to=cast_to,
#    1054     remaining_retries=remaining,
#    1055     stream=stream,
#    1056     stream_cls=stream_cls,
#    1057 )
#
# File c:\Users\Rajveer.Mathur\OneDrive - Brillio\Desktop\EY\.venv\Lib\site-packages\groq\_base_client.py:975, in SyncAPIClient._request(self, cast_to, options, remaining_retries, stream, stream_cls)
#     972 log.debug("Encountered Exception", exc_info=True)
#     974 if retries > 0:
# --> 975     return self._retry_request(
#     976         options,
#     977         cast_to,
#     978         retries,
#     979         stream=stream,
#     980         stream_cls=stream_cls,
#     981         response_headers=None,
#     982     )
#     984 log.debug("Raising connection error")
#     985 raise APIConnectionError(request=request) from err
#
# File c:\Users\Rajveer.Mathur\OneDrive - Brillio\Desktop\EY\.venv\Lib\site-packages\groq\_base_client.py:1051, in SyncAPIClient._retry_request(self, options, cast_to, remaining_retries, response_headers, stream, stream_cls)
#    1047 # In a synchronous context we are blocking the entire thread. Up to the library user to run the client in a
#    1048 # different thread if necessary.
#    1049 time.sleep(timeout)
# -> 1051 return self._request(
#    1052     options=options,
#    1053     cast_to=cast_to,
#    1054     remaining_retries=remaining,
#    1055     stream=stream,
#    1056     stream_cls=stream_cls,
#    1057 )
#
# File c:\Users\Rajveer.Mathur\OneDrive - Brillio\Desktop\EY\.venv\Lib\site-packages\groq\_base_client.py:985, in SyncAPIClient._request(self, cast_to, options, remaining_retries, stream, stream_cls)
#     975         return self._retry_request(
#     976             options,
#     977             cast_to,
#    (...)
#     981             response_headers=None,
#     982         )
#     984     log.debug("Raising connection error")
# --> 985     raise APIConnectionError(request=request) from err
#     987 log.debug(
#     988     'HTTP Response: %s %s "%i %s" %s',
#     989     request.method,
#    (...)
#     993     response.headers,
#     994 )
#     996 try:
#
# APIConnectionError: Connection error.
